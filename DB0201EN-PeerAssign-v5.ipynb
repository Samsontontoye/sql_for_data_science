# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# <h1 align=center><font size = 5>Assignment: Notebook for Peer Assignment</font></h1>

# %% [markdown]
# # Introduction
#
# Using this Python notebook you will:
#
# 1.  Understand three Chicago datasets
# 2.  Load the three datasets into three tables in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Understand the datasets
#
# To complete the assignment problems in this notebook you will be using three datasets that are available on the city of Chicago's Data Portal:
#
# 1.  <a href="https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Socioeconomic Indicators in Chicago</a>
# 2.  <a href="https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Chicago Public Schools</a>
# 3.  <a href="https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Chicago Crime Data</a>
#
# ### 1. Socioeconomic Indicators in Chicago
#
# This dataset contains a selection of six socioeconomic indicators of public health significance and a “hardship index,” for each Chicago community area, for the years 2008 – 2012.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2](https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 2. Chicago Public Schools
#
# This dataset shows all school level performance data used to create CPS School Report Cards for the 2011-2012 school year. This dataset is provided by the city of Chicago's Data Portal.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t](https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 3. Chicago Crime Data
#
# This dataset reflects reported incidents of crime (with the exception of murders where data exists for each victim) that occurred in the City of Chicago from 2001 to present, minus the most recent seven days.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to have these three tables populated with a subset of the whole datasets.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the links below to download and save the datasets (.CSV files):
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Chicago Census Data</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Chicago Public Schools</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Chicago Crime Data</a>
#
# **NOTE:** Ensure you have downloaded the datasets using the links above instead of directly from the Chicago Data Portal. The versions linked here are subsets of the original datasets and have some of the column names modified to be more database friendly which will make it easier to complete this assignment.

# %% [markdown]
# ### Store the datasets in database tables
#
# To analyze the data using SQL, it first needs to be stored in the database.
#
# While it is easier to read the dataset into a Pandas dataframe and then PERSIST it into the database as we saw in Week 3 Lab 3, it results in mapping to default datatypes which may not be optimal for SQL querying. For example a long textual field may map to a CLOB instead of a VARCHAR.
#
# Therefore, **it is highly recommended to manually load the table using the database console LOAD tool, as indicated in Week 2 Lab 1 Part II**. The only difference with that lab is that in Step 5 of the instructions you will need to click on create "(+) New Table" and specify the name of the table you want to create and then click "Next".
#
# <img src = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/images/LoadingData.png">
#
# ##### Now open the Db2 console, open the LOAD tool, Select / Drag the .CSV file for the first dataset, Next create a New Table, and then follow the steps on-screen instructions to load the data. Name the new tables as follows:
#
# 1.  **CENSUS_DATA**
# 2.  **CHICAGO_PUBLIC_SCHOOLS**
# 3.  **CHICAGO_CRIME_DATA**

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# !pip install sqlalchemy==1.3.9
# !pip install ibm_db_sa
# Out:
# Requirement already satisfied: sqlalchemy==1.3.9 in c:\users\hp\desktop\personal_projects\ibm_data_analyst_professional_certificate\sql_for_data_science\env\lib\site-packages (1.3.9)
# Requirement already satisfied: ibm_db_sa in c:\users\hp\desktop\personal_projects\ibm_data_analyst_professional_certificate\sql_for_data_science\env\lib\site-packages (0.3.7)
# Requirement already satisfied: sqlalchemy>=0.7.3 in c:\users\hp\desktop\personal_projects\ibm_data_analyst_professional_certificate\sql_for_data_science\env\lib\site-packages (from ibm_db_sa) (1.3.9)
# Requirement already satisfied: ibm-db>=2.0.0 in c:\users\hp\desktop\personal_projects\ibm_data_analyst_professional_certificate\sql_for_data_science\env\lib\site-packages (from ibm_db_sa) (3.0.4)

# %%
# %load_ext sql

# %% [markdown]
# In the next cell enter your db2 connection string. Recall you created Service Credentials for your Db2 instance in first lab in Week 3. From your Db2 service credentials copy everything after db2:// (except the double quote at the end) and paste it in the cell below after ibm_db_sa://
#
# <img src ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/images/details.png">

# %%
# Remember the connection string is of the format:
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name?security=SSL
# Enter the connection string for your Db2 on Cloud database instance below
# %sql ibm_db_sa://jhr98298:KptCwBD4QWk7bjF6@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB?security=SSL

# %% [markdown]
# ## Problems
#
# Now write and execute SQL queries to solve assignment problems
#
# ### Problem 1
#
# ##### Find the total number of crimes recorded in the CRIME table.

# %%
# %sql SELECT COUNT(*) from Crime_Data
# Out:
#  * ibm_db_sa://jhr98298:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [(533,)]

# %% [markdown]
# ### Problem 2
#
# ##### List community areas with per capita income less than 11000.

# %%
# %sql SELECT COMMUNITY_AREA_NAME, PER_CAPITA_INCOME FROM CENSUS_DATA \
     where PER_CAPITA_INCOME < 11000
# Out:
#  * ibm_db_sa://jhr98298:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [('West Garfield Park', 10934),
#  ('South Lawndale', 10402),
#  ('Fuller Park', 10432),
#  ('Riverdale', 8201)]

# %% [markdown]
# ### Problem 3
#
# ##### List all case numbers for crimes  involving minors?(children are not considered minors for the purposes of crime analysis)

# %%
# %sql SELECT CASE_NUMBER, PRIMARY_TYPE from CRIME_DATA
# Out:
#  * ibm_db_sa://jhr98298:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [('HK587712', 'THEFT'),
#  ('HK456306', 'THEFT'),
#  ('HT233595', 'THEFT'),
#  ('HT133522', 'THEFT'),
#  ('HZ138551', 'THEFT'),
#  ('HS540106', 'THEFT'),
#  ('HZ534771', 'THEFT'),
#  ('HL793243', 'THEFT'),
#  ('HL149610', 'THEFT'),
#  ('HK361551', 'THEFT'),
#  ('HX552797', 'THEFT'),
#  ('HT180228', 'THEFT'),
#  ('HV243612', 'THEFT'),
#  ('HN200365', 'THEFT'),
#  ('HK108680', 'THEFT'),
#  ('HY396729', 'THEFT'),
#  ('HR271603', 'THEFT'),
#  ('HX332132', 'THEFT'),
#  ('HW303994', 'THEFT'),
#  ('HS569246', 'THEFT'),
#  ('HY234744', 'THEFT'),
#  ('HP320451', 'THEFT'),
#  ('HN484464', 'THEFT'),
#  ('JB151690', 'THEFT'),
#  ('HR582990', 'THEFT'),
#  ('HR535632', 'THEFT'),
#  ('HH486939', 'THEFT'),
#  ('HW441620', 'THEFT'),
#  ('HJ561433', 'THEFT'),
#  ('HR583513', 'THEFT'),
#  ('HX509438', 'THEFT'),
#  ('HS681158', 'THEFT'),
#  ('HK350670', 'THEFT'),
#  ('G256545', 'THEFT'),
#  ('JA272438', 'THEFT'),
#  ('HH201585', 'THEFT'),
#  ('G212935', 'THEFT'),
#  ('HL590300', 'THEFT'),
#  ('HL409680', 'THEFT'),
#  ('HM324025', 'THEFT'),
#  ('G662598', 'THEFT'),
#  ('HV353560', 'THEFT'),
#  ('HR261581', 'THEFT'),
#  ('HL680775', 'THEFT'),
#  ('HM543491', 'THEFT'),
#  ('HY167451', 'THEFT'),
#  ('HY377901', 'THEFT'),
#  ('HX225704', 'THEFT'),
#  ('HJ308632', 'THEFT'),
#  ('HV528008', 'THEFT'),
#  ('HK801112', 'THEFT'),
#  ('HS532107', 'THEFT'),
#  ('JA261898', 'THEFT'),
#  ('JA559176', 'THEFT'),
#  ('JA412895', 'THEFT'),
#  ('HY273740', 'THEFT'),
#  ('HZ224258', 'THEFT'),
#  ('HJ652747', 'THEFT'),
#  ('G040244', 'THEFT'),
#  ('HJ415128', 'THEFT'),
#  ('HV534721', 'THEFT'),
#  ('JA503725', 'THEFT'),
#  ('HM803061', 'THEFT'),
#  ('HN731220', 'THEFT'),
#  ('HP691879', 'THEFT'),
#  ('HV537004', 'THEFT'),
#  ('HR149903', 'THEFT'),
#  ('HX314361', 'THEFT'),
#  ('HV345270', 'THEFT'),
#  ('HS308747', 'THEFT'),
#  ('HK728309', 'THEFT'),
#  ('HL005270', 'THEFT'),
#  ('HY291329', 'THEFT'),
#  ('HJ678713', 'THEFT'),
#  ('HY412959', 'THEFT'),
#  ('HX155070', 'THEFT'),
#  ('HV402967', 'THEFT'),
#  ('HX332979', 'THEFT'),
#  ('HJ710634', 'THEFT'),
#  ('HX165034', 'THEFT'),
#  ('HR385117', 'THEFT'),
#  ('HS230912', 'THEFT'),
#  ('HL177398', 'THEFT'),
#  ('HH702524', 'THEFT'),
#  ('JA384163', 'THEFT'),
#  ('HJ672058', 'THEFT'),
#  ('HT368471', 'THEFT'),
#  ('HY202462', 'THEFT'),
#  ('HX354359', 'THEFT'),
#  ('HZ146741', 'THEFT'),
#  ('G376790', 'THEFT'),
#  ('HX262353', 'THEFT'),
#  ('HP317516', 'THEFT'),
#  ('HZ335434', 'THEFT'),
#  ('HS678732', 'THEFT'),
#  ('HL382289', 'THEFT'),
#  ('HM392612', 'THEFT'),
#  ('HH869886', 'THEFT'),
#  ('HR460350', 'THEFT'),
#  ('HM117889', 'THEFT'),
#  ('HR576816', 'THEFT'),
#  ('HZ372381', 'THEFT'),
#  ('HZ556726', 'THEFT'),
#  ('HN421595', 'THEFT'),
#  ('HK454598', 'THEFT'),
#  ('HH657809', 'THEFT'),
#  ('HS451246', 'BATTERY'),
#  ('HH316735', 'BATTERY'),
#  ('G597730', 'BATTERY'),
#  ('G736811', 'BATTERY'),
#  ('HT651635', 'BATTERY'),
#  ('HZ432273', 'BATTERY'),
#  ('G517474', 'BATTERY'),
#  ('HP746347', 'BATTERY'),
#  ('G056330', 'BATTERY'),
#  ('HN772519', 'BATTERY'),
#  ('HZ309936', 'BATTERY'),
#  ('HY368284', 'BATTERY'),
#  ('HL353697', 'BATTERY'),
#  ('HT375934', 'BATTERY'),
#  ('JA188596', 'BATTERY'),
#  ('HL725506', 'BATTERY'),
#  ('HV395700', 'BATTERY'),
#  ('HH696901', 'BATTERY'),
#  ('HT390647', 'BATTERY'),
#  ('HK815196', 'BATTERY'),
#  ('JA490957', 'BATTERY'),
#  ('HK103473', 'BATTERY'),
#  ('HM556695', 'BATTERY'),
#  ('HH558381', 'BATTERY'),
#  ('HK498590', 'BATTERY'),
#  ('HX455839', 'BATTERY'),
#  ('HR703960', 'BATTERY'),
#  ('HL646682', 'BATTERY'),
#  ('HV445580', 'BATTERY'),
#  ('G688026', 'BATTERY'),
#  ('HJ466766', 'BATTERY'),
#  ('HL632721', 'BATTERY'),
#  ('HP579910', 'BATTERY'),
#  ('HL718742', 'BATTERY'),
#  ('HP714065', 'BATTERY'),
#  ('HP716225', 'BATTERY'),
#  ('HW481295', 'BATTERY'),
#  ('HS568476', 'BATTERY'),
#  ('JB213238', 'BATTERY'),
#  ('HS475732', 'BATTERY'),
#  ('HS595785', 'BATTERY'),
#  ('HR408597', 'BATTERY'),
#  ('HT542713', 'BATTERY'),
#  ('HL240985', 'BATTERY'),
#  ('HJ254782', 'BATTERY'),
#  ('HK561262', 'BATTERY'),
#  ('HW213573', 'BATTERY'),
#  ('G419948', 'BATTERY'),
#  ('HL177008', 'BATTERY'),
#  ('HJ639869', 'BATTERY'),
#  ('HM217017', 'BATTERY'),
#  ('HL388623', 'BATTERY'),
#  ('HY189363', 'BATTERY'),
#  ('HS498285', 'BATTERY'),
#  ('HN224900', 'BATTERY'),
#  ('HR387668', 'BATTERY'),
#  ('HJ294892', 'BATTERY'),
#  ('HL745027', 'BATTERY'),
#  ('G533278', 'BATTERY'),
#  ('HH827769', 'BATTERY'),
#  ('HH639427', 'BATTERY'),
#  ('HK771992', 'BATTERY'),
#  ('HH867007', 'BATTERY'),
#  ('HJ575773', 'BATTERY'),
#  ('HR136920', 'BATTERY'),
#  ('HT457930', 'BATTERY'),
#  ('G070193', 'BATTERY'),
#  ('HJ724585', 'BATTERY'),
#  ('HP121474', 'BATTERY'),
#  ('G198370', 'BATTERY'),
#  ('HJ723825', 'BATTERY'),
#  ('HJ458342', 'BATTERY'),
#  ('HP558812', 'BATTERY'),
#  ('HY192694', 'BATTERY'),
#  ('HN472326', 'BATTERY'),
#  ('HK756778', 'BATTERY'),
#  ('HH741961', 'BATTERY'),
#  ('JA460432', 'BATTERY'),
#  ('G140454', 'BATTERY'),
#  ('HX239866', 'BATTERY'),
#  ('HM378171', 'BATTERY'),
#  ('HW182288', 'BATTERY'),
#  ('HZ295843', 'BATTERY'),
#  ('HM673431', 'BATTERY'),
#  ('HP352546', 'BATTERY'),
#  ('HR286405', 'BATTERY'),
#  ('HR195987', 'BATTERY'),
#  ('HW261668', 'BATTERY'),
#  ('JA496716', 'BATTERY'),
#  ('JA344492', 'BATTERY'),
#  ('HZ334220', 'BATTERY'),
#  ('HR217367', 'BATTERY'),
#  ('HV268964', 'CRIMINAL DAMAGE'),
#  ('JA483294', 'CRIMINAL DAMAGE'),
#  ('HT169840', 'CRIMINAL DAMAGE'),
#  ('HT621306', 'CRIMINAL DAMAGE'),
#  ('HS269736', 'CRIMINAL DAMAGE'),
#  ('HK243330', 'CRIMINAL DAMAGE'),
#  ('HH262924', 'CRIMINAL DAMAGE'),
#  ('HW557360', 'CRIMINAL TRESPA'),
#  ('HJ776916', 'CRIMINAL TRESPA'),
#  ('HJ419340', 'CRIMINAL TRESPA'),
#  ('HH329720', 'CRIMINAL TRESPA'),
#  ('HM802052', 'CRIMINAL TRESPA'),
#  ('HJ804627', 'CRIMINAL TRESPA'),
#  ('HR190881', 'CRIMINAL TRESPA'),
#  ('G575031', 'CRIMINAL TRESPA'),
#  ('G122095', 'PROSTITUTION'),
#  ('HN595319', 'PROSTITUTION'),
#  ('G302291', 'PROSTITUTION'),
#  ('G057394', 'PROSTITUTION'),
#  ('HM590468', 'PROSTITUTION'),
#  ('HV463112', 'PROSTITUTION'),
#  ('HK749575', 'WEAPONS VIOLATI'),
#  ('HS100098', 'WEAPONS VIOLATI'),
#  ('HW576249', 'WEAPONS VIOLATI'),
#  ('HK485601', 'WEAPONS VIOLATI'),
#  ('HH460583', 'WEAPONS VIOLATI'),
#  ('HM576559', 'WEAPONS VIOLATI'),
#  ('HL611297', 'PUBLIC PEACE VI'),
#  ('HV356389', 'PUBLIC PEACE VI'),
#  ('HX203242', 'PUBLIC PEACE VI'),
#  ('HH292682', 'PUBLIC PEACE VI'),
#  ('G635735', 'PUBLIC PEACE VI'),
#  ('HN567387', 'OFFENSE INVOLVI'),
#  ('HR391350', 'OFFENSE INVOLVI'),
#  ('HM768251', 'OFFENSE INVOLVI'),
#  ('HT394616', 'OFFENSE INVOLVI'),
#  ('HH688935', 'CRIM SEXUAL ASS'),
#  ('HK677648', 'CRIM SEXUAL ASS'),
#  ('G158614', 'CRIM SEXUAL ASS'),
#  ('HK310265', 'SEX OFFENSE'),
#  ('HR314298', 'SEX OFFENSE'),
#  ('HT404326', 'SEX OFFENSE'),
#  ('HY259084', 'INTERFERENCE WI'),
#  ('HL415544', 'INTERFERENCE WI'),
#  ('HP265256', 'GAMBLING'),
#  ('HR392537', 'GAMBLING'),
#  ('HL266884', 'LIQUOR LAW VIOL'),
#  ('HK238408', 'LIQUOR LAW VIOL'),
#  ('HX343113', 'ARSON'),
#  ('HM195342', 'ARSON'),
#  ('HW519443', 'HOMICIDE'),
#  ('JA359626', 'HOMICIDE'),
#  ('HN144152', 'KIDNAPPING'),
#  ('HN544458', 'INTIMIDATION'),
#  ('HW238778', 'STALKING'),
#  ('JB155558', 'OBSCENITY'),
#  ('HY458571', 'CONCEALED CARRY'),
#  ('HZ378869', 'PUBLIC INDECENC'),
#  ('HZ378355', 'NON-CRIMINAL'),
#  ('HX258445', 'OTHER NARCOTIC '),
#  ('HZ192829', 'HUMAN TRAFFICKI'),
#  ('HZ133234', 'NON - CRIMINAL'),
#  ('HJ747227', 'RITUALISM'),
#  ('JA143710', 'NON-CRIMINAL (S'),
#  ('G021609', 'DOMESTIC VIOLEN')]

# %% [markdown]
# ### Problem 4
#
# ##### List all kidnapping crimes involving a child?

# %%
# %sql SELECT COUNT(*) from CRIME_DATA \
     where PRIMARY_TYPE = 'KIDNAPPING'
# Out:
#  * ibm_db_sa://jhr98298:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [(1,)]

# %% [markdown]
# ### Problem 5
#
# ##### What kinds of crimes were recorded at schools?

# %%
# %sql SELECT PRIMARY_TYPE, LOCATION_DESCRIPTION from CRIME_DATA \
     where LOCATION_DESCRIPTION = 'SCHOOL,PUBLIC,BUILDING'
# Out:
#  * ibm_db_sa://jhr98298:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# []

# %% [markdown]
# ### Problem 6
#
# ##### List the average safety score for all types of schools.

# %%
# %sql SELECT NAME_OF_SCHOOL, SAFETY_SCORE FROM SCHOOLS \
    WHERE SAFETY_SCORE = (SELECT AVG(SAFETY_SCORE) from SCHOOLS)
# Out:
#  * ibm_db_sa://jhr98298:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [('Air Force Academy High School', 49),
#  ('Alexander Graham Elementary School', 49),
#  ('Francisco I Madero Middle School', 49),
#  ('George B McClellan Elementary School', 49),
#  ('Graeme Stewart Elementary School', 49),
#  ('Ida B Wells Preparatory Elementary Academy', 49),
#  ('James Ward Elementary School', 49),
#  ('Matthew Gallistel Elementary Language Academy', 49),
#  ('Nathan R Goldblatt Elementary School', 49),
#  ('William Bishop Owen Scholastic Academy Elementary School', 49),
#  ('Williams Preparatory Academy Middle School', 49)]

# %% [markdown]
# ### Problem 7
#
# ##### List 5 community areas with highest % of households below poverty line

# %%
# %sql select COMMUNITY_AREA_NAME, PERCENT_HOUSEHOLDS_BELOW_POVERTY AS HOUSEHOLD_BELOW_POVERTY_LINE \
     FROM CENSUS_DATA \
     order by PERCENT_HOUSEHOLDS_BELOW_POVERTY \
     limit 5
# Out:
#  * ibm_db_sa://jhr98298:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [('Edison Park', Decimal('3.3')),
#  ('Mount Greenwood', Decimal('3.4')),
#  ('Beverly', Decimal('5.1')),
#  ('Norwood Park', Decimal('5.4')),
#  ('North Center', Decimal('7.5'))]

# %% [markdown]
# ### Problem 8
#
# ##### Which community area is most crime prone?

# %%
# %sql SELECT BLOCK, DESCRIPTION AS CRIME_PRONE from CRIME_DATA \
     where ARREST = "True"
# Out:
#  * ibm_db_sa://jhr98298:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [('005XX E PERSHING RD', 'RETAIL THEFT'),
#  ('076XX S CICERO AVE', 'RETAIL THEFT'),
#  ('089XX S STONY ISLAND AVE', 'RETAIL THEFT'),
#  ('008XX N MICHIGAN AVE', 'RETAIL THEFT'),
#  ('036XX S ARCHER AVE', 'RETAIL THEFT'),
#  ('045XX S DAMEN AV', '$500 AND UNDER'),
#  ('0000X W ELM ST', 'RETAIL THEFT'),
#  ('0000X N STATE ST', '$500 AND UNDER'),
#  ('017XX W CERMAK RD', 'RETAIL THEFT'),
#  ('063XX N NAGLE AV', '$500 AND UNDER'),
#  ('058XX S ASHLAND AVE', '$500 AND UNDER'),
#  ('029XX N ASHLAND AVE', 'RETAIL THEFT'),
#  ('076XX S CICERO AVE', 'RETAIL THEFT'),
#  ('0000X S STATE ST', '$500 AND UNDER'),
#  ('048XX W NORTH AVE', '$500 AND UNDER'),
#  ('023XX W ROSCOE ST', 'SIMPLE'),
#  ('078XX S SAWYER AV', 'SIMPLE'),
#  ('024XX S TROY ST', 'DOMESTIC BATTERY SIMPLE'),
#  ('013XX W 49TH PL', 'AGG PO HANDS NO/MIN INJURY'),
#  ('048XX N FRANCISCO AVE', 'PRO EMP HANDS NO/MIN INJURY'),
#  ('011XX N LA SALLE DR', 'DOMESTIC BATTERY SIMPLE'),
#  ('034XX N HALSTED ST', 'SIMPLE'),
#  ('016XX S ST LOUIS AVE', 'DOMESTIC BATTERY SIMPLE'),
#  ('025XX N HALSTED ST', 'SIMPLE'),
#  ('072XX S STONY ISLAND AVE', 'DOMESTIC BATTERY SIMPLE'),
#  ('001XX N STATE ST', 'SIMPLE'),
#  ('021XX W 63RD ST', 'SIMPLE'),
#  ('0000X E 69TH ST', 'SIMPLE'),
#  ('040XX W IRVING PARK RD', 'AGGRAVATED DOMESTIC BATTERY'),
#  ('016XX W MADISON ST', 'SIMPLE'),
#  ('044XX S PRINCETON AVE', 'SIMPLE'),
#  ('001XX W 75TH ST', 'AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON'),
#  ('008XX N WASHTENAW AVE', 'DOMESTIC BATTERY SIMPLE'),
#  ('009XX E 132ND PL', 'DOMESTIC BATTERY SIMPLE'),
#  ('023XX W PRATT BLVD', 'SIMPLE'),
#  ('066XX S CALIFORNIA AVE', 'TO PROPERTY'),
#  ('013XX S HOMAN AVE', 'TO VEHICLE'),
#  ('014XX W CHICAGO AVE', 'TO PROPERTY'),
#  ('057XX S HAMILTON AV', 'TO PROPERTY'),
#  ('031XX N NEWCASTLE AVE', 'TO PROPERTY'),
#  ('109XX S MICHIGAN AVE', 'TO PROPERTY'),
#  ('137XX S BRAINARD AVE', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('001XX W 87TH ST', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('048XX N WINTHROP AVE', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('004XX N LARAMIE AVE', 'POSS: HEROIN(WHITE)'),
#  ('071XX S STONY ISLAND AVE', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('002XX S WHIPPLE ST', 'POSS: HEROIN(WHITE)'),
#  ('007XX S CALIFORNIA AV', 'POSS: HEROIN(WHITE)'),
#  ('016XX W JONQUIL TER', 'POSS: HEROIN(WHITE)'),
#  ('041XX W 87TH ST', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('035XX S WASHTENAW AVE', 'MANU/DEL:CANNABIS 10GM OR LESS'),
#  ('047XX W FULTON ST', 'MANU/DELIVER: HEROIN (WHITE)'),
#  ('100XX W OHARE ST', 'POSS: CRACK'),
#  ('003XX S WESTERN AVE', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('040XX W WILCOX ST', 'POSS: CRACK'),
#  ('033XX W FILLMORE ST', 'FOUND SUSPECT NARCOTICS'),
#  ('042XX N MARINE DR', 'MANU/DELIVER: METHAMPHETAMINES'),
#  ('074XX S PAXTON AV', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('071XX S MICHIGAN AVE', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('004XX N PINE AVE', 'POSS: CRACK'),
#  ('055XX S WELLS ST', 'POSS: HEROIN(WHITE)'),
#  ('013XX S CHRISTIANA AVE', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('011XX W WILSON AVE', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('084XX S SAGINAW AVE', 'POSS: CRACK'),
#  ('038XX S ROCKWELL ST', 'POSS: COCAINE'),
#  ('056XX S ARTESIAN AVE', 'POSS: CRACK'),
#  ('006XX E 51ST ST', 'MANU/DELIVER: HEROIN (WHITE)'),
#  ('031XX W FIFTH AVE', 'ATTEMPT POSSESSION NARCOTICS'),
#  ('059XX S CAMPBELL AVE', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('079XX S ELIZABETH ST', 'POSS: COCAINE'),
#  ('008XX N HOMAN AVE', 'SOLICIT NARCOTICS ON PUBLICWAY'),
#  ('051XX S EMERALD AVE', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('062XX S DREXEL AVE', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('005XX E MARQUETTE RD', 'POSS: HEROIN(WHITE)'),
#  ('051XX W MADISON ST', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('048XX S WOOD ST', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('017XX S HAMILTON AVE', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('039XX W LEXINGTON ST', 'MANU/DELIVER: HEROIN (WHITE)'),
#  ('013XX W 13TH ST', 'ATTEMPT POSSESSION NARCOTICS'),
#  ('008XX N KEELER AVE', 'SOLICIT NARCOTICS ON PUBLICWAY'),
#  ('119XX S PARNELL AVE', 'SOLICIT NARCOTICS ON PUBLICWAY'),
#  ('008XX W EASTWOOD AVE', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('039XX W 19TH ST', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('006XX N RIDGEWAY AVE', 'POSS: HEROIN(WHITE)'),
#  ('009XX N HAMLIN AVE', 'MANU/DELIVER:CRACK'),
#  ('014XX N AVERS AVE', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('007XX N MONTICELLO AVE', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('053XX W ADDISON ST', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('009XX N LOREL AVE', 'MANU/DELIVER: HEROIN (WHITE)'),
#  ('049XX W MAYPOLE AVE', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('012XX N LOCKWOOD AVE', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('078XX S COTTAGE GROVE AVE', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('033XX W 38TH ST', 'POSS: CANNABIS 30GMS OR LESS'),
#  ('062XX S KEDZIE AVE', 'POSS: CRACK'),
#  ('058XX S KEELER AVE', 'VIOLATE ORDER OF PROTECTION'),
#  ('011XX N PULASKI RD', 'PAROLE VIOLATION'),
#  ('026XX E 103RD ST', 'FALSE/STOLEN/ALTERED TRP'),
#  ('020XX E 79TH ST', 'FALSE/STOLEN/ALTERED TRP'),
#  ('007XX S KENNETH AVE', 'OTHER VEHICLE OFFENSE'),
#  ('006XX W 61ST ST', 'VIOLATE ORDER OF PROTECTION'),
#  ('0000X N WALLER AVE', 'OTHER VEHICLE OFFENSE'),
#  ('015XX W 18TH PL', 'AGGRAVATED: OTHER DANG WEAPON'),
#  ('103XX S DOTY AVE E', 'AGGRAVATED PO: OTHER DANG WEAP'),
#  ('009XX W MARQUETTE RD', 'SIMPLE'),
#  ('038XX W MONROE ST', 'AGGRAVATED: HANDGUN'),
#  ('047XX S FORRESTVILLE AV', 'SIMPLE'),
#  ('008XX E 65TH ST', 'AGGRAVATED: HANDGUN'),
#  ('0000X W CHICAGO AVE', 'SIMPLE'),
#  ('064XX S PEORIA DR', 'SIMPLE'),
#  ('064XX S MORGAN ST', 'AGGRAVATED:KNIFE/CUTTING INSTR'),
#  ('026XX N SEMINARY AVE', 'FORCIBLE ENTRY'),
#  ('035XX W FRANKLIN BL', 'AUTOMOBILE'),
#  ('023XX W GRAND AVE', 'THEFT OF LOST/MISLAID PROP'),
#  ('004XX N STATE ST', 'THEFT BY LESSEE,MOTOR VEH'),
#  ('016XX W HOWARD ST', 'THEFT OF LOST/MISLAID PROP'),
#  ('034XX N CLARK ST', 'THEFT OF LABOR/SERVICES'),
#  ('011XX W WILSON AV', 'THEFT OF LABOR/SERVICES'),
#  ('057XX S CICERO AV', 'FRAUD OR CONFIDENCE GAME'),
#  ('027XX W ARDMORE AVE', 'STRONGARM - NO WEAPON'),
#  ('036XX N WESTERN AVE', 'STRONGARM - NO WEAPON'),
#  ('046XX N SACRAMENTO AVE', 'STRONGARM - NO WEAPON'),
#  ('029XX S DEARBORN ST', 'TO STATE SUP LAND'),
#  ('027XX S STATE ST', 'TO STATE SUP LAND'),
#  ('094XX S HARVARD AVE', 'TO RESIDENCE'),
#  ('043XX W 79TH ST', 'TO LAND'),
#  ('079XX S HALSTED ST', 'TO LAND'),
#  ('062XX S TALMAN AVE', 'TO LAND'),
#  ('025XX N PULASKI RD', 'TO LAND'),
#  ('004XX S STATE ST', 'TO LAND'),
#  ('003XX S MAPLEWOOD AVE', 'TO STATE SUP LAND'),
#  ('031XX S DEARBORN ST', 'TO LAND'),
#  ('005XX E 36TH PL', 'TO STATE SUP LAND'),
#  ('002XX W ADAMS ST', 'TO LAND'),
#  ('0000X W 87 ST', 'TO LAND'),
#  ('039XX N ASHLAND AV', 'CALL OPERATION'),
#  ('070XX N CLARK ST', 'SOLICIT ON PUBLIC WAY'),
#  ('026XX W MADISON ST', 'SOLICIT ON PUBLIC WAY'),
#  ('046XX S CICERO AV', 'SOLICIT FOR BUSINESS'),
#  ('010XX N STATE ST', 'SOLICIT ON PUBLIC WAY'),
#  ('0000X N KENTON AVE', 'SOLICIT ON PUBLIC WAY'),
#  ('070XX S ROCKWELL ST', 'UNLAWFUL POSS OTHER FIREARM'),
#  ('012XX S KEDVALE AVE', 'UNLAWFUL POSS OF HANDGUN'),
#  ('067XX S THROOP ST', 'UNLAWFUL POSS OF HANDGUN'),
#  ('021XX N ST LOUIS AVE', 'UNLAWFUL POSS OF HANDGUN'),
#  ('087XX S ESCANABA AVE', 'UNLAWFUL POSS OF HANDGUN'),
#  ('046XX S LEAMINGTON AVE', 'RECKLESS CONDUCT'),
#  ('063XX S EBERHART AVE', 'RECKLESS CONDUCT'),
#  ('0000X N HERMITAGE AV', 'BOMB THREAT'),
#  ('076XX S CAMPBELL AVE', 'CRIM SEX ABUSE BY FAM MEMBER'),
#  ('022XX N KOSTNER AVE', 'NON-AGGRAVATED'),
#  ('007XX W 49TH PL', 'OTHER'),
#  ('023XX N MASON AVE', 'AGG CRIMINAL SEXUAL ABUSE'),
#  ('031XX W FLOURNOY ST', 'ESCAPE'),
#  ('013XX N HUDSON AVE', 'GAME/DICE'),
#  ('070XX S TALMAN AVE', 'GAME/DICE'),
#  ('024XX N CLARK ST', 'SELL/GIVE/DEL LIQUOR TO MINOR'),
#  ('093XX S STONY ISLAND AVE', 'ILLEGAL CONSUMPTION BY MINOR'),
#  ('044XX S RICHMOND ST', 'FIRST DEGREE MURDER'),
#  ('036XX W 81ST ST', 'OBSCENE MATTER'),
#  ('059XX W CHICAGO AVE', 'OTHER'),
#  ('008XX W 76TH ST', 'LICENSED PREMISE'),
#  ('010XX N WELLS ST', 'INTOXICATING COMPOUNDS'),
#  ('087XX S ESCANABA AV', 'DOMESTIC VIOLENCE')]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Query for the 'community area number' that is most crime prone.
# -->

# %% [markdown]
# ### Problem 9
#
# ##### Use a sub-query to find the name of the community area with highest hardship index

# %%
# %sql SELECT COMMUNITY_AREA_NAME FROM CENSUS_DATA \
     WHERE HARDSHIP_INDEX IN (SELECT MAX(HARDSHIP_INDEX) FROM CENSUS_DATA)
# Out:
#  * ibm_db_sa://jhr98298:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [('Riverdale',)]

# %% [markdown]
# ### Problem 10
#
# ##### Use a sub-query to determine the Community Area Name with most number of crimes?

# %%
# %sql SELECT BLOCK, PRIMARY_TYPE FROM CRIME_DATA \
     WHERE PRIMARY_TYPE = (SELECT MAX(PRIMARY_TYPE) FROM CRIME_DATA)
# Out:
#  * ibm_db_sa://jhr98298:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [('002XX N LARAMIE AVE', 'WEAPONS VIOLATI'),
#  ('070XX S ROCKWELL ST', 'WEAPONS VIOLATI'),
#  ('012XX S KEDVALE AVE', 'WEAPONS VIOLATI'),
#  ('067XX S THROOP ST', 'WEAPONS VIOLATI'),
#  ('021XX N ST LOUIS AVE', 'WEAPONS VIOLATI'),
#  ('087XX S ESCANABA AVE', 'WEAPONS VIOLATI')]

# %% [markdown]
# Copyright © 2020 [cognitiveclass.ai](cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).

# %% [markdown]
# ## Author(s)
#
# <h4> Hima Vasudevan </h4>
# <h4> Rav Ahuja </h4>
# <h4> Ramesh Sannreddy </h4>
#
# ## Contribtuor(s)
#
# <h4> Malika Singla </h4>
#
# ## Change log
#
# | Date       | Version | Changed by        | Change Description                             |
# | ---------- | ------- | ----------------- | ---------------------------------------------- |
# | 2021-05-19 | 2.4     | Lakshmi Holla     | Updated the question                           |
# | 2021-04-30 | 2.3     | Malika Singla     | Updated the libraries                          |
# | 2021-01-15 | 2.2     | Rav Ahuja         | Removed problem 11 and fixed changelog         |
# | 2020-11-25 | 2.1     | Ramesh Sannareddy | Updated the problem statements, and datasets   |
# | 2020-09-05 | 2.0     | Malika Singla     | Moved lab to course repo in GitLab             |
# | 2018-07-18 | 1.0     | Rav Ahuja         | Several updates including loading instructions |
# | 2018-05-04 | 0.1     | Hima Vasudevan    | Created initial version                        |
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
